# %%
import pandas as pd

# %%
df = pd.read_csv("data/Colorado River Basin Water Conflict Table.csv")

# %%
# set pandas display all columns in data frames
pd.set_option("display.max.columns", None)

# %% [markdown]
# ## exploring the data

# %%
# get summary stats
df.describe()
# Out:
#             Event  Report Year  Event Day  Event Month   Event Year  \
# count  268.000000   265.000000  18.000000   212.000000   257.000000
# mean   134.500000  2017.449057  18.444444     6.259434  2016.591440
# std     77.509139     4.314160   6.887518     3.679539    10.346365
# min      1.000000  2005.000000   4.000000     1.000000  1900.000000
# 25%     67.750000  2015.000000  13.250000     3.000000  2015.000000
# 50%    134.500000  2019.000000  19.000000     5.000000  2019.000000
# 75%    201.250000  2021.000000  20.000000     9.000000  2021.000000
# max    268.000000  2022.000000  31.000000    12.000000  2023.000000
#
#         County FIPS  Intensity Value  Article Text Search - water quality  \
# count      8.000000       255.000000                           268.000000
# mean   11170.500000         0.219608                             0.671642
# std    15437.657326         1.995765                             1.472729
# ...

# %%
# get technical info on dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 48 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Event                                         268 non-null    int64
#  1   Search Source                                 268 non-null    object
#  2   Newspaper                                     268 non-null    object
#  3   Article Title                                 268 non-null    object
#  4   Duplicate                                     267 non-null    object
#  5   Report Date                                   267 non-null    object
#  6   Report Year                                   265 non-null    float64
#  7   Event Date                                    248 non-null    object
#  8   Event Day                                     18 non-null     float64
# ...

# %%
# get df dimensions
df.shape
# Out:
# (268, 48)

# %%
# get num of NAs in each column
df.isna().sum()
# Out:
# Event                                             0
# Search Source                                     0
# Newspaper                                         0
# Article Title                                     0
# Duplicate                                         1
# Report Date                                       1
# Report Year                                       3
# Event Date                                       20
# Event Day                                       250
# Event Month                                      56
# Event Year                                       11
# Conflict Present                                 16
# Crisis Present                                   14
# Basin                                            18
# HUC6                                            158
# HUC2                                             18
# Place                                            14
# County                                          260
# ...
